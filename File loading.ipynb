# %% [markdown]
# For food_orders.json, your questions can be:
#
#     What is the total revenue?
#
#     Which restaurant earns the most?
#
#     Which item is ordered most?
#
#     What is the most used payment mode?

# %%
import json

#Load the json file
def load_data(filename):
    with open(filename,"r") as file:
        data = json.load(file)
    return data

# Display Order
def display_order(data):
    print("Order IDs ")
    for order in data:
        print(f"ID : {order['order_id']} - Date : {order['date']} - Restaurant : {order['restaurant']} - Item : {order['item']} - Price : {order['price']} - Quantity : {order['quantity']} - Payment_mode : {order['payment_mode']}")

#Load and display data
data = load_data("food_orders.json")
display_order(data)
# Out:
# Order IDs
# ID : 301 - Date : 2024-03-01 - Restaurant : Spice Hub - Item : Paneer Butter Masala - Price : 220 - Quantity : 2 - Payment_mode : UPI
# ID : 302 - Date : 2024-03-01 - Restaurant : Burger Town - Item : Veg Burger - Price : 120 - Quantity : 3 - Payment_mode : Cash
# ID : 303 - Date : 2024-03-02 - Restaurant : Pizza Palace - Item : Margherita Pizza - Price : 300 - Quantity : 1 - Payment_mode : Card
# ID : 304 - Date : 2024-03-02 - Restaurant : Spice Hub  - Item : Dal Fry - Price : 180 - Quantity : 2 - Payment_mode : upi
# ID : 305 - Date : 2024-03-03 - Restaurant : Burger Town - Item : French Fries - Price : 90 - Quantity : 4 - Payment_mode : UPI
# ID : 306 - Date : 2024-03-03 - Restaurant : Pizza Palace - Item : Farmhouse Pizza - Price : 450 - Quantity : 1 - Payment_mode : CARD
# ID : 307 - Date : 2024-03-04 - Restaurant : Spice Hub - Item : Jeera Rice - Price : 150 - Quantity : 2 - Payment_mode : Card
# ID : 306 - Date : 2024-03-03 - Restaurant : Pizza Palace - Item : Farmhouse Pizza - Price : 450 - Quantity : 1 - Payment_mode : card
# ID : 308 - Date : 2024-03-04 - Restaurant : Burger Town - Item : Veg Burger - Price : 120 - Quantity : 0 - Payment_mode : UPI
# ID : 309 - Date : 2024-03-05 - Restaurant : Spice Hub - Item : Paneer Butter Masala - Price : 220 - Quantity : 3 - Payment_mode : Cash
